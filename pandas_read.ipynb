# %%
! type test.txt
# Out:
# 1,2,3,4
# 5,6,7,8

# %%
import pandas as pd

# %%
df = pd.read_csv('test.txt')

# %%
df
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#       <td>8</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
pd.read_csv('test.txt',header = None)
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#       <td>8</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
pd.read_csv('test.txt',names=['x1','x2','x3','x4'])
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>x1</th>
#       <th>x2</th>
#       <th>x3</th>
#       <th>x4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#       <td>8</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
open('test.txt')
# Out:
# <_io.TextIOWrapper name='test.txt' mode='r' encoding='cp936'>

# %%
result=pd.read_csv('test.txt')

# %%
result
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#       <td>8</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
result = pd.read_table('test.txt',sep=',')

# %%
result
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#       <td>8</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
result = pd.read_table('test1.txt',sep='\s+')

# %%
result
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>x1</th>
#       <th>x2</th>
#       <th>x3</th>
#       <th>x4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5</td>
#       <td>6</td>
#       <td>7</td>
#       <td>8</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
result=pd.read_csv('test1.txt')

# %%
result
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>x1 x2 x3 x4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1 2 3 4</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5 6 7 8</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df1=pd.read_csv('test1.txt',skiprows=[1,3])

# %%
df1
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>x1 x2 x3 x4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>5 6 7 8</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>13 14 15 16</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>17 18 19 20</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
pd.read_excel('km.xlsx',sheetname="Sheet1",nrow=1000)
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>x1</th>
#       <th>x2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>166.388200</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>162.151233</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>163.525933</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>164.735233</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>171.801667</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>197.366227</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>7</td>
#       <td>144.208267</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>8</td>
#       <td>122.735667</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>9</td>
#       <td>116.641667</td>
#     </tr>
# ...

# %%
pd.read_csv('data.csv')
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Num</th>
#       <th>Item</th>
#       <th>Driver_Desp_Num</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>16</td>
#       <td>0</td>
#       <td>40</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>17</td>
#       <td>1</td>
#       <td>41</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>18</td>
#       <td>0</td>
#       <td>42</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>20</td>
#       <td>1</td>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>21</td>
#       <td>0</td>
#       <td>47</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>22</td>
#       <td>0</td>
#       <td>49</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>23</td>
#       <td>1</td>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>27</td>
# ...

# %%
pd.read_csv('data.csv',nrows=10)
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Num</th>
#       <th>Item</th>
#       <th>Driver_Desp_Num</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>16</td>
#       <td>0</td>
#       <td>40</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>17</td>
#       <td>1</td>
#       <td>41</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>18</td>
#       <td>0</td>
#       <td>42</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>20</td>
#       <td>1</td>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>21</td>
#       <td>0</td>
#       <td>47</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>22</td>
#       <td>0</td>
#       <td>49</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>23</td>
#       <td>1</td>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>27</td>
# ...

# %%
chunker = pd.read_csv('data.csv',chunksize=20)

# %%
from pandas import Series,DataFrame

# %%
tot = Series([])

# %%
data = pd.read_csv('data.csv')

# %%
data
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Num</th>
#       <th>Item</th>
#       <th>Driver_Desp_Num</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>16</td>
#       <td>0</td>
#       <td>40</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>17</td>
#       <td>1</td>
#       <td>41</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>18</td>
#       <td>0</td>
#       <td>42</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>20</td>
#       <td>1</td>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>21</td>
#       <td>0</td>
#       <td>47</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>22</td>
#       <td>0</td>
#       <td>49</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>23</td>
#       <td>1</td>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>27</td>
# ...

# %%
data.to_csv('out.csv')
